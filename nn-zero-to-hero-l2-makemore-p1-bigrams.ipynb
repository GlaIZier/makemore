# %%
with open("names.txt", "r") as f:
    for line in f.read().splitlines():
        # line = line.strip()
        print("." + line[:-1])
        print(line[1:] + ".")
        for l1, l2 in zip("." + line[:-1], line[1:] + "."):
            print(l1, l2)
        print(line)
        break
# Out:
# .emm
# mma.
# . m
# e m
# m a
# m .
# emma
